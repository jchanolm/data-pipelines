# %% [markdown]
# ## Initial ingest
#
# ### Context
# Ingest manually collected data on grants and grantees into a Neo4J database
# to establish a basis for future enhancements through the development of ingestion pipelines
# for on/off-chain data.
#
#
# Very sloppy but doing what I can on short notice :)

# %%
import os 
import pandas as pd
import time
import neo4j
from neo4j import GraphDatabase

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
## Neo4J auth
## Free Neo4J instances are available via Neo4J aura - https://neo4j.com/cloud/aura-free/ 
NEO4J_URI = os.getenv('NEO4J_URI')
NEO4J_PASS = os.getenv('NEO4J_PASS')
neo4j_client = GraphDatabase.driver(NEO4J_URI, auth=('neo4j', NEO4J_PASS))
retrieval = "InitialIngest"

def execute_query(query, params=None, neo4j=neo4j):
    with neo4j_client.session() as session:
        result = session.run(query, parameters=params)
        # Convert the result to a DataFrame
        records = [record.data() for record in result]
        return pd.DataFrame(records)

# %% [markdown]
# # `grantees.csv`
# Ingest `Grantees` who received Arbitrum Foundation funds, directly or through matching programs.
#
# ## Grantee
# Purposefully minimal -- identifiers are separate nodes to facilitate reconciliation for future ingests
#
# `(grantee:Entity:Grantee {name})`

# %%
grantees_filname = 'grantees_20240303.csv'
grantees_df = pd.read_csv(f'inputs/{grantees_filname}')
print(f"There are {len(grantees_df)} grantees to ingest")
# Out:
# There are 152 grantees to ingest

# %%
## iterate through df and create entities
### todo - use LOAD JSON | LOAD CSV for efficiency
    

def create_grantees(df):
    total = len(df)
    counter = 0 
    for index, row in df.iterrows():
        counter += 1
        print(f"Ingesting grantee {str(counter)} of {total}...")

        params = {
            'name': row['Name']
        }
        
        query = """
        MERGE (entity:Grantee:Entity {name: $name})
        """
        execute_query(query, params)

create_grantees(grantees_df)
# Out:
# Ingesting grantee 1 of 152...
# Ingesting grantee 2 of 152...
# Ingesting grantee 3 of 152...
# Ingesting grantee 4 of 152...
# Ingesting grantee 5 of 152...
# Ingesting grantee 6 of 152...
# Ingesting grantee 7 of 152...
# Ingesting grantee 8 of 152...
# Ingesting grantee 9 of 152...
# Ingesting grantee 10 of 152...
# Ingesting grantee 11 of 152...
# Ingesting grantee 12 of 152...
# Ingesting grantee 13 of 152...
# Ingesting grantee 14 of 152...
# Ingesting grantee 15 of 152...
# Ingesting grantee 16 of 152...
# Ingesting grantee 17 of 152...
# Ingesting grantee 18 of 152...
# Ingesting grantee 19 of 152...
# Ingesting grantee 20 of 152...
# Ingesting grantee 21 of 152...
# Ingesting grantee 22 of 152...
# Ingesting grantee 23 of 152...
# Ingesting grantee 24 of 152...
# Ingesting grantee 25 of 152...
# Ingesting grantee 26 of 152...
# Ingesting grantee 27 of 152...
# Ingesting grantee 28 of 152...
# Ingesting grantee 29 of 152...
# Ingesting grantee 30 of 152...
# Ingesting grantee 31 of 152...
# Ingesting grantee 32 of 152...
# Ingesting grantee 33 of 152...
# Ingesting grantee 34 of 152...
# Ingesting grantee 35 of 152...
# Ingesting grantee 36 of 152...
# Ingesting grantee 37 of 152...
# Ingesting grantee 38 of 152...
# Ingesting grantee 39 of 152...
# Ingesting grantee 40 of 152...
# Ingesting grantee 41 of 152...
# Ingesting grantee 42 of 152...
# Ingesting grantee 43 of 152...
# Ingesting grantee 44 of 152...
# Ingesting grantee 45 of 152...
# Ingesting grantee 46 of 152...
# Ingesting grantee 47 of 152...
# Ingesting grantee 48 of 152...
# Ingesting grantee 49 of 152...
# Ingesting grantee 50 of 152...
# Ingesting grantee 51 of 152...
# Ingesting grantee 52 of 152...
# Ingesting grantee 53 of 152...
# Ingesting grantee 54 of 152...
# Ingesting grantee 55 of 152...
# Ingesting grantee 56 of 152...
# Ingesting grantee 57 of 152...
# Ingesting grantee 58 of 152...
# Ingesting grantee 59 of 152...
# Ingesting grantee 60 of 152...
# Ingesting grantee 61 of 152...
# Ingesting grantee 62 of 152...
# Ingesting grantee 63 of 152...
# Ingesting grantee 64 of 152...
# Ingesting grantee 65 of 152...
# Ingesting grantee 66 of 152...
# Ingesting grantee 67 of 152...
# Ingesting grantee 68 of 152...
# Ingesting grantee 69 of 152...
# Ingesting grantee 70 of 152...
# Ingesting grantee 71 of 152...
# Ingesting grantee 72 of 152...
# Ingesting grantee 73 of 152...
# Ingesting grantee 74 of 152...
# Ingesting grantee 75 of 152...
# Ingesting grantee 76 of 152...
# Ingesting grantee 77 of 152...
# Ingesting grantee 78 of 152...
# Ingesting grantee 79 of 152...
# Ingesting grantee 80 of 152...
# Ingesting grantee 81 of 152...
# Ingesting grantee 82 of 152...
# Ingesting grantee 83 of 152...
# Ingesting grantee 84 of 152...
# Ingesting grantee 85 of 152...
# Ingesting grantee 86 of 152...
# Ingesting grantee 87 of 152...
# Ingesting grantee 88 of 152...
# Ingesting grantee 89 of 152...
# Ingesting grantee 90 of 152...
# Ingesting grantee 91 of 152...
# Ingesting grantee 92 of 152...
# Ingesting grantee 93 of 152...
# Ingesting grantee 94 of 152...
# Ingesting grantee 95 of 152...
# Ingesting grantee 96 of 152...
# Ingesting grantee 97 of 152...
# Ingesting grantee 98 of 152...
# Ingesting grantee 99 of 152...
# Ingesting grantee 100 of 152...
# Ingesting grantee 101 of 152...
# Ingesting grantee 102 of 152...
# Ingesting grantee 103 of 152...
# Ingesting grantee 104 of 152...
# Ingesting grantee 105 of 152...
# Ingesting grantee 106 of 152...
# Ingesting grantee 107 of 152...
# Ingesting grantee 108 of 152...
# Ingesting grantee 109 of 152...
# Ingesting grantee 110 of 152...
# Ingesting grantee 111 of 152...
# Ingesting grantee 112 of 152...
# Ingesting grantee 113 of 152...
# Ingesting grantee 114 of 152...
# Ingesting grantee 115 of 152...
# Ingesting grantee 116 of 152...
# Ingesting grantee 117 of 152...
# Ingesting grantee 118 of 152...
# Ingesting grantee 119 of 152...
# Ingesting grantee 120 of 152...
# Ingesting grantee 121 of 152...
# Ingesting grantee 122 of 152...
# Ingesting grantee 123 of 152...
# Ingesting grantee 124 of 152...
# Ingesting grantee 125 of 152...
# Ingesting grantee 126 of 152...
# Ingesting grantee 127 of 152...
# Ingesting grantee 128 of 152...
# Ingesting grantee 129 of 152...
# Ingesting grantee 130 of 152...
# Ingesting grantee 131 of 152...
# Ingesting grantee 132 of 152...
# Ingesting grantee 133 of 152...
# Ingesting grantee 134 of 152...
# Ingesting grantee 135 of 152...
# Ingesting grantee 136 of 152...
# Ingesting grantee 137 of 152...
# Ingesting grantee 138 of 152...
# Ingesting grantee 139 of 152...
# Ingesting grantee 140 of 152...
# Ingesting grantee 141 of 152...
# Ingesting grantee 142 of 152...
# Ingesting grantee 143 of 152...
# Ingesting grantee 144 of 152...
# Ingesting grantee 145 of 152...
# Ingesting grantee 146 of 152...
# Ingesting grantee 147 of 152...
# Ingesting grantee 148 of 152...
# Ingesting grantee 149 of 152...
# Ingesting grantee 150 of 152...
# Ingesting grantee 151 of 152...
# Ingesting grantee 152 of 152...

# %%
## verify grantees created
execute_query("""MATCH (grantee:Grantee) RETURN COUNT(*)""")
# Out:
#    COUNT(*)
# 0       152

# %% [markdown]
# ## Grantee identifiers
#
# Identifiers are broken out as separate nodes because they can or maintain their own relationships (i.e. a GitHub account contributes to Repos, Twitter Account posts Tweets)
#
# ### Todos
#
# Set `.url` as property on `:Account` nodes where applicable.
#
#
# **Twitter**
#
# `(grantee:Grantee)-[r:ACCOUNT]->(twitter:Twitter:Account {handle})`
#
#
# **Github**
#
# `(grantee:Grantee)-[r:ACCOUNT]->(github:Website:Account {url})`
#
# **Wallet**
#
# `(grantee:Grantee)-[r:ACCOUNT {source}]->(wallet:Wallet {address})`
#
# *(note: add label for multisigs)*
#
# *(note: add sources when ingest `grants.csv`)*
#
# So on and so forth...

# %%
## twitter

counter = 0 
grantees_df_twitter = grantees_df[['Name', 'Twitter']] 
grantees_df_twitter = grantees_df_twitter.dropna(subset=['Twitter'])
total = len(grantees_df_twitter)

print(f"Ingesting {str(total)} twitter accounts...")
counter = 0 

for index, row in grantees_df_twitter.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'handle': row['Twitter'],
        'name': row['Name']
    }
    
    query = """
    merge (twitter:Twitter:Account {handle: $handle}) 
    with twitter
    match (grantee:Grantee {name: $name}) 
    with grantee, twitter
    merge (grantee)-[r:ACCOUNT]->(twitter)
    """
    execute_query(query, params)

execute_query("""match (grantee:Grantee)-[r]-(twitter:Twitter) return count(distinct(r)) as linked_twitters""")
# Out:
# Ingesting 116 twitter accounts...
# Ingesting 1 of 116 records...
# Ingesting 2 of 116 records...
# Ingesting 3 of 116 records...
# Ingesting 4 of 116 records...
# Ingesting 5 of 116 records...
# Ingesting 6 of 116 records...
# Ingesting 7 of 116 records...
# Ingesting 8 of 116 records...
# Ingesting 9 of 116 records...
# Ingesting 10 of 116 records...
# Ingesting 11 of 116 records...
# Ingesting 12 of 116 records...
# Ingesting 13 of 116 records...
# Ingesting 14 of 116 records...
# Ingesting 15 of 116 records...
# Ingesting 16 of 116 records...
# Ingesting 17 of 116 records...
# Ingesting 18 of 116 records...
# Ingesting 19 of 116 records...
# Ingesting 20 of 116 records...
# Ingesting 21 of 116 records...
# Ingesting 22 of 116 records...
# Ingesting 23 of 116 records...
# Ingesting 24 of 116 records...
# Ingesting 25 of 116 records...
# Ingesting 26 of 116 records...
# Ingesting 27 of 116 records...
# Ingesting 28 of 116 records...
# Ingesting 29 of 116 records...
# Ingesting 30 of 116 records...
# Ingesting 31 of 116 records...
# Ingesting 32 of 116 records...
# Ingesting 33 of 116 records...
# Ingesting 34 of 116 records...
# Ingesting 35 of 116 records...
# Ingesting 36 of 116 records...
# Ingesting 37 of 116 records...
# Ingesting 38 of 116 records...
# Ingesting 39 of 116 records...
# Ingesting 40 of 116 records...
# Ingesting 41 of 116 records...
# Ingesting 42 of 116 records...
# Ingesting 43 of 116 records...
# Ingesting 44 of 116 records...
# Ingesting 45 of 116 records...
# Ingesting 46 of 116 records...
# Ingesting 47 of 116 records...
# Ingesting 48 of 116 records...
# Ingesting 49 of 116 records...
# Ingesting 50 of 116 records...
# Ingesting 51 of 116 records...
# Ingesting 52 of 116 records...
# Ingesting 53 of 116 records...
# Ingesting 54 of 116 records...
# Ingesting 55 of 116 records...
# Ingesting 56 of 116 records...
# Ingesting 57 of 116 records...
# Ingesting 58 of 116 records...
# Ingesting 59 of 116 records...
# Ingesting 60 of 116 records...
# Ingesting 61 of 116 records...
# Ingesting 62 of 116 records...
# Ingesting 63 of 116 records...
# Ingesting 64 of 116 records...
# Ingesting 65 of 116 records...
# Ingesting 66 of 116 records...
# Ingesting 67 of 116 records...
# Ingesting 68 of 116 records...
# Ingesting 69 of 116 records...
# Ingesting 70 of 116 records...
# Ingesting 71 of 116 records...
# Ingesting 72 of 116 records...
# Ingesting 73 of 116 records...
# Ingesting 74 of 116 records...
# Ingesting 75 of 116 records...
# Ingesting 76 of 116 records...
# Ingesting 77 of 116 records...
# Ingesting 78 of 116 records...
# Ingesting 79 of 116 records...
# Ingesting 80 of 116 records...
# Ingesting 81 of 116 records...
# Ingesting 82 of 116 records...
# Ingesting 83 of 116 records...
# Ingesting 84 of 116 records...
# Ingesting 85 of 116 records...
# Ingesting 86 of 116 records...
# Ingesting 87 of 116 records...
# Ingesting 88 of 116 records...
# Ingesting 89 of 116 records...
# Ingesting 90 of 116 records...
# Ingesting 91 of 116 records...
# Ingesting 92 of 116 records...
# Ingesting 93 of 116 records...
# Ingesting 94 of 116 records...
# Ingesting 95 of 116 records...
# Ingesting 96 of 116 records...
# Ingesting 97 of 116 records...
# Ingesting 98 of 116 records...
# Ingesting 99 of 116 records...
# Ingesting 100 of 116 records...
# Ingesting 101 of 116 records...
# Ingesting 102 of 116 records...
# Ingesting 103 of 116 records...
# Ingesting 104 of 116 records...
# Ingesting 105 of 116 records...
# Ingesting 106 of 116 records...
# Ingesting 107 of 116 records...
# Ingesting 108 of 116 records...
# Ingesting 109 of 116 records...
# Ingesting 110 of 116 records...
# Ingesting 111 of 116 records...
# Ingesting 112 of 116 records...
# Ingesting 113 of 116 records...
# Ingesting 114 of 116 records...
# Ingesting 115 of 116 records...
# Ingesting 116 of 116 records...
#    linked_twitters
# 0              116

# %%
## ingest websites

## twitter

counter = 0 
grantees_df_websites = grantees_df[['Name', 'Website']] 
grantees_df_websites = grantees_df_websites.dropna(subset=['Website'])
total = len(grantees_df_websites)

print(f"Ingesting {str(total)} websites...")
counter = 0 

for index, row in grantees_df_websites.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'url': row['Website'],
        'name': row['Name']
    }
    
    query = """
    merge (website:Website:Account {url: $url}) 
    with website
    match (grantee:Grantee {name: $name}) 
    with grantee, website
    merge (grantee)-[r:ACCOUNT]->(website)
    """
    execute_query(query, params)

execute_query("""match (grantee:Grantee)-[r]-(website:Website) return count(distinct(r)) as linked_websites""")
# Out:
# Ingesting 121 websites...
# Ingesting 1 of 121 records...
# Ingesting 2 of 121 records...
# Ingesting 3 of 121 records...
# Ingesting 4 of 121 records...
# Ingesting 5 of 121 records...
# Ingesting 6 of 121 records...
# Ingesting 7 of 121 records...
# Ingesting 8 of 121 records...
# Ingesting 9 of 121 records...
# Ingesting 10 of 121 records...
# Ingesting 11 of 121 records...
# Ingesting 12 of 121 records...
# Ingesting 13 of 121 records...
# Ingesting 14 of 121 records...
# Ingesting 15 of 121 records...
# Ingesting 16 of 121 records...
# Ingesting 17 of 121 records...
# Ingesting 18 of 121 records...
# Ingesting 19 of 121 records...
# Ingesting 20 of 121 records...
# Ingesting 21 of 121 records...
# Ingesting 22 of 121 records...
# Ingesting 23 of 121 records...
# Ingesting 24 of 121 records...
# Ingesting 25 of 121 records...
# Ingesting 26 of 121 records...
# Ingesting 27 of 121 records...
# Ingesting 28 of 121 records...
# Ingesting 29 of 121 records...
# Ingesting 30 of 121 records...
# Ingesting 31 of 121 records...
# Ingesting 32 of 121 records...
# Ingesting 33 of 121 records...
# Ingesting 34 of 121 records...
# Ingesting 35 of 121 records...
# Ingesting 36 of 121 records...
# Ingesting 37 of 121 records...
# Ingesting 38 of 121 records...
# Ingesting 39 of 121 records...
# Ingesting 40 of 121 records...
# Ingesting 41 of 121 records...
# Ingesting 42 of 121 records...
# Ingesting 43 of 121 records...
# Ingesting 44 of 121 records...
# Ingesting 45 of 121 records...
# Ingesting 46 of 121 records...
# Ingesting 47 of 121 records...
# Ingesting 48 of 121 records...
# Ingesting 49 of 121 records...
# Ingesting 50 of 121 records...
# Ingesting 51 of 121 records...
# Ingesting 52 of 121 records...
# Ingesting 53 of 121 records...
# Ingesting 54 of 121 records...
# Ingesting 55 of 121 records...
# Ingesting 56 of 121 records...
# Ingesting 57 of 121 records...
# Ingesting 58 of 121 records...
# Ingesting 59 of 121 records...
# Ingesting 60 of 121 records...
# Ingesting 61 of 121 records...
# Ingesting 62 of 121 records...
# Ingesting 63 of 121 records...
# Ingesting 64 of 121 records...
# Ingesting 65 of 121 records...
# Ingesting 66 of 121 records...
# Ingesting 67 of 121 records...
# Ingesting 68 of 121 records...
# Ingesting 69 of 121 records...
# Ingesting 70 of 121 records...
# Ingesting 71 of 121 records...
# Ingesting 72 of 121 records...
# Ingesting 73 of 121 records...
# Ingesting 74 of 121 records...
# Ingesting 75 of 121 records...
# Ingesting 76 of 121 records...
# Ingesting 77 of 121 records...
# Ingesting 78 of 121 records...
# Ingesting 79 of 121 records...
# Ingesting 80 of 121 records...
# Ingesting 81 of 121 records...
# Ingesting 82 of 121 records...
# Ingesting 83 of 121 records...
# Ingesting 84 of 121 records...
# Ingesting 85 of 121 records...
# Ingesting 86 of 121 records...
# Ingesting 87 of 121 records...
# Ingesting 88 of 121 records...
# Ingesting 89 of 121 records...
# Ingesting 90 of 121 records...
# Ingesting 91 of 121 records...
# Ingesting 92 of 121 records...
# Ingesting 93 of 121 records...
# Ingesting 94 of 121 records...
# Ingesting 95 of 121 records...
# Ingesting 96 of 121 records...
# Ingesting 97 of 121 records...
# Ingesting 98 of 121 records...
# Ingesting 99 of 121 records...
# Ingesting 100 of 121 records...
# Ingesting 101 of 121 records...
# Ingesting 102 of 121 records...
# Ingesting 103 of 121 records...
# Ingesting 104 of 121 records...
# Ingesting 105 of 121 records...
# Ingesting 106 of 121 records...
# Ingesting 107 of 121 records...
# Ingesting 108 of 121 records...
# Ingesting 109 of 121 records...
# Ingesting 110 of 121 records...
# Ingesting 111 of 121 records...
# Ingesting 112 of 121 records...
# Ingesting 113 of 121 records...
# Ingesting 114 of 121 records...
# Ingesting 115 of 121 records...
# Ingesting 116 of 121 records...
# Ingesting 117 of 121 records...
# Ingesting 118 of 121 records...
# Ingesting 119 of 121 records...
# Ingesting 120 of 121 records...
# Ingesting 121 of 121 records...
#    linked_websites
# 0              121

# %%
## ingest Githubs

## twitter

counter = 0 
grantees_df_githubs = grantees_df[['Name', 'Github']] 
grantees_df_githubs = grantees_df_githubs.dropna(subset=['Github'])
total = len(grantees_df_githubs)

print(f"Ingesting {str(total)} github accounts...")
counter = 0 

for index, row in grantees_df_githubs.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'handle': row['Github'],
        'name': row['Name']
    }
    
    query = """
    merge (github:Github:Account {handle: $handle}) 
    with github
    match (grantee:Grantee {name: $name}) 
    with grantee, github
    merge (grantee)-[r:ACCOUNT]->(github)
    """
    execute_query(query, params)

execute_query("""match (grantee:Grantee)-[r]-(github:Github) return count(distinct(r)) as linked_githubs""")
# Out:
# Ingesting 61 github accounts...
# Ingesting 1 of 61 records...
# Ingesting 2 of 61 records...
# Ingesting 3 of 61 records...
# Ingesting 4 of 61 records...
# Ingesting 5 of 61 records...
# Ingesting 6 of 61 records...
# Ingesting 7 of 61 records...
# Ingesting 8 of 61 records...
# Ingesting 9 of 61 records...
# Ingesting 10 of 61 records...
# Ingesting 11 of 61 records...
# Ingesting 12 of 61 records...
# Ingesting 13 of 61 records...
# Ingesting 14 of 61 records...
# Ingesting 15 of 61 records...
# Ingesting 16 of 61 records...
# Ingesting 17 of 61 records...
# Ingesting 18 of 61 records...
# Ingesting 19 of 61 records...
# Ingesting 20 of 61 records...
# Ingesting 21 of 61 records...
# Ingesting 22 of 61 records...
# Ingesting 23 of 61 records...
# Ingesting 24 of 61 records...
# Ingesting 25 of 61 records...
# Ingesting 26 of 61 records...
# Ingesting 27 of 61 records...
# Ingesting 28 of 61 records...
# Ingesting 29 of 61 records...
# Ingesting 30 of 61 records...
# Ingesting 31 of 61 records...
# Ingesting 32 of 61 records...
# Ingesting 33 of 61 records...
# Ingesting 34 of 61 records...
# Ingesting 35 of 61 records...
# Ingesting 36 of 61 records...
# Ingesting 37 of 61 records...
# Ingesting 38 of 61 records...
# Ingesting 39 of 61 records...
# Ingesting 40 of 61 records...
# Ingesting 41 of 61 records...
# Ingesting 42 of 61 records...
# Ingesting 43 of 61 records...
# Ingesting 44 of 61 records...
# Ingesting 45 of 61 records...
# Ingesting 46 of 61 records...
# Ingesting 47 of 61 records...
# Ingesting 48 of 61 records...
# Ingesting 49 of 61 records...
# Ingesting 50 of 61 records...
# Ingesting 51 of 61 records...
# Ingesting 52 of 61 records...
# Ingesting 53 of 61 records...
# Ingesting 54 of 61 records...
# Ingesting 55 of 61 records...
# Ingesting 56 of 61 records...
# Ingesting 57 of 61 records...
# Ingesting 58 of 61 records...
# Ingesting 59 of 61 records...
# Ingesting 60 of 61 records...
# Ingesting 61 of 61 records...
#    linked_githubs
# 0              61

# %%
## ingest Dune

## twitter

counter = 0 
grantees_df_dunes = grantees_df[['Name', 'Dune']] 
grantees_df_dunes = grantees_df_dunes.dropna(subset=['Dune'])
total = len(grantees_df_dunes)

print(f"Ingesting {str(total)} dune accounts...")
counter = 0 

for index, row in grantees_df_dunes.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'handle': row['Dune'],
        'name': row['Name']
    }
    
    query = """
    merge (dune:Dune:Account {handle: $handle}) 
    with dune
    match (grantee:Grantee {name: $name}) 
    merge (grantee)-[r:ACCOUNT]->(dune)
    """
    execute_query(query, params)

execute_query("""match (grantee:Grantee)-[r]-(dune:Dune) return count(distinct(r)) as linked_dunes""")
# Out:
# Ingesting 4 dune accounts...
# Ingesting 1 of 4 records...
# Ingesting 2 of 4 records...
# Ingesting 3 of 4 records...
# Ingesting 4 of 4 records...
#    linked_dunes
# 0             4

# %%
## ingest wallets

counter = 0 
grantees_df_wallets = grantees_df[['Name', 'Funding Wallet Address']] 
grantees_df_wallets = grantees_df_wallets.dropna(subset=['Funding Wallet Address'])
total = len(grantees_df_wallets)

print(f"Ingesting {str(total)} wallets...")
counter = 0 

for index, row in grantees_df_wallets.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'address': row['Funding Wallet Address'],
        'name': row['Name']
    }
    
    query = """
    merge (wallet:Wallet:Account {address: tolower($address)}) 
    with wallet
    match (grantee:Grantee {name: $name}) 
    merge (grantee)-[r:ACCOUNT]->(wallet)
    """
    execute_query(query, params)
    time.sleep(.5)

execute_query("""match (grantee:Grantee)-[r]-(wallet:Wallet) return count(distinct(r)) as linked_wallets""")
# Out:
# Ingesting 114 wallets...
# Ingesting 1 of 114 records...
# Ingesting 2 of 114 records...
# Ingesting 3 of 114 records...
# Ingesting 4 of 114 records...
# Ingesting 5 of 114 records...
# Ingesting 6 of 114 records...
# Ingesting 7 of 114 records...
# Ingesting 8 of 114 records...
# Ingesting 9 of 114 records...
# Ingesting 10 of 114 records...
# Ingesting 11 of 114 records...
# Ingesting 12 of 114 records...
# Ingesting 13 of 114 records...
# Ingesting 14 of 114 records...
# Ingesting 15 of 114 records...
# Ingesting 16 of 114 records...
# Ingesting 17 of 114 records...
# Ingesting 18 of 114 records...
# Ingesting 19 of 114 records...
# Ingesting 20 of 114 records...
# Ingesting 21 of 114 records...
# Ingesting 22 of 114 records...
# Ingesting 23 of 114 records...
# Ingesting 24 of 114 records...
# Ingesting 25 of 114 records...
# Ingesting 26 of 114 records...
# Ingesting 27 of 114 records...
# Ingesting 28 of 114 records...
# Ingesting 29 of 114 records...
# Ingesting 30 of 114 records...
# Ingesting 31 of 114 records...
# Ingesting 32 of 114 records...
# Ingesting 33 of 114 records...
# Ingesting 34 of 114 records...
# Ingesting 35 of 114 records...
# Ingesting 36 of 114 records...
# Ingesting 37 of 114 records...
# Ingesting 38 of 114 records...
# Ingesting 39 of 114 records...
# Ingesting 40 of 114 records...
# Ingesting 41 of 114 records...
# Ingesting 42 of 114 records...
# Ingesting 43 of 114 records...
# Ingesting 44 of 114 records...
# Ingesting 45 of 114 records...
# Ingesting 46 of 114 records...
# Ingesting 47 of 114 records...
# Ingesting 48 of 114 records...
# Ingesting 49 of 114 records...
# Ingesting 50 of 114 records...
# Ingesting 51 of 114 records...
# Ingesting 52 of 114 records...
# Ingesting 53 of 114 records...
# Ingesting 54 of 114 records...
# Ingesting 55 of 114 records...
# Ingesting 56 of 114 records...
# Ingesting 57 of 114 records...
# Ingesting 58 of 114 records...
# Ingesting 59 of 114 records...
# Ingesting 60 of 114 records...
# Ingesting 61 of 114 records...
# Ingesting 62 of 114 records...
# Ingesting 63 of 114 records...
# Ingesting 64 of 114 records...
# Ingesting 65 of 114 records...
# Ingesting 66 of 114 records...
# Ingesting 67 of 114 records...
# Ingesting 68 of 114 records...
# Ingesting 69 of 114 records...
# Ingesting 70 of 114 records...
# Ingesting 71 of 114 records...
# Ingesting 72 of 114 records...
# Ingesting 73 of 114 records...
# Ingesting 74 of 114 records...
# Ingesting 75 of 114 records...
# Ingesting 76 of 114 records...
# Ingesting 77 of 114 records...
# Ingesting 78 of 114 records...
# Ingesting 79 of 114 records...
# Ingesting 80 of 114 records...
# Ingesting 81 of 114 records...
# Ingesting 82 of 114 records...
# Ingesting 83 of 114 records...
# Ingesting 84 of 114 records...
# Ingesting 85 of 114 records...
# Ingesting 86 of 114 records...
# Ingesting 87 of 114 records...
# Ingesting 88 of 114 records...
# Ingesting 89 of 114 records...
# Ingesting 90 of 114 records...
# Ingesting 91 of 114 records...
# Ingesting 92 of 114 records...
# Ingesting 93 of 114 records...
# Ingesting 94 of 114 records...
# Ingesting 95 of 114 records...
# Ingesting 96 of 114 records...
# Ingesting 97 of 114 records...
# Ingesting 98 of 114 records...
# Ingesting 99 of 114 records...
# Ingesting 100 of 114 records...
# Ingesting 101 of 114 records...
# Ingesting 102 of 114 records...
# Ingesting 103 of 114 records...
# Ingesting 104 of 114 records...
# Ingesting 105 of 114 records...
# Ingesting 106 of 114 records...
# Ingesting 107 of 114 records...
# Ingesting 108 of 114 records...
# Ingesting 109 of 114 records...
# Ingesting 110 of 114 records...
# Ingesting 111 of 114 records...
# Ingesting 112 of 114 records...
# Ingesting 113 of 114 records...
# Ingesting 114 of 114 records...
#    linked_wallets
# 0             114

# %% [markdown]
# ## Ingest other grantees
#
# `other_grantees_initial.csv` has Arbitrum ecosystem projects which I haven't collected structured grant data for yet
# (i.e. they've received grants but I don't have the grant metadata structured yet)

# %%
other_grantees_filname = 'inputs/other_grantees_initial.csv'
other_grantees_df = pd.read_csv(other_grantees_filname)

print(f"There are {len(other_grantees_df)} records to ingest")

other_grantees_df.head(3)
# Out:
# There are 22 records to ingest
#                name                                            website  \
# 0  ArbitrumNews DAO                   https://link3.to/arbitrumnewsdao
# 1             Burns  https://forum.arbitrum.foundation/t/rfp-abitru...
# 2              Raho                                       raho.me/stip
#
#            twitter           github  \
# 0  ArbitrumNewsDAO  ArbitrumNewsDAO
# 1      mitchburns_       burns-unit
# 2       raholloway            raho1
#
#                                               source platform
# 0  https://checker.gitcoin.co/public/project/show...  Gitcoin
# 1  https://checker.gitcoin.co/public/project/show...  Gitcoin
# 2  https://checker.gitcoin.co/public/project/show...  Gitcoin

# %%
## ingest wallets

counter = 0 
total = len(other_grantees_df)

for index, row in other_grantees_df.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'name': row['name']
    }
    
    query = """
    merge (grantee:Grantee:Entity {name: $name}) 
    """
    execute_query(query, params)
    time.sleep(.5)

execute_query("""match (grantee:Grantee) return count(grantee) as other_grantees""")
# Out:
# Ingesting 1 of 22 records...
# Ingesting 2 of 22 records...
# Ingesting 3 of 22 records...
# Ingesting 4 of 22 records...
# Ingesting 5 of 22 records...
# Ingesting 6 of 22 records...
# Ingesting 7 of 22 records...
# Ingesting 8 of 22 records...
# Ingesting 9 of 22 records...
# Ingesting 10 of 22 records...
# Ingesting 11 of 22 records...
# Ingesting 12 of 22 records...
# Ingesting 13 of 22 records...
# Ingesting 14 of 22 records...
# Ingesting 15 of 22 records...
# Ingesting 16 of 22 records...
# Ingesting 17 of 22 records...
# Ingesting 18 of 22 records...
# Ingesting 19 of 22 records...
# Ingesting 20 of 22 records...
# Ingesting 21 of 22 records...
# Ingesting 22 of 22 records...
#    other_grantees
# 0             165

# %%
## ingest other grantee metadata

other_twitter = other_grantees_df[['name', 'twitter']]
other_twitter = other_twitter.dropna(subset=['twitter'])

for index, row in other_twitter.iterrows():
    url = "https://twitter.com/" + row['twitter'] 
    params = {
        'handle': row['twitter'],
        'url': url,
        'name': row['name']
    }
    query = """
        merge (twitter:Account:Twitter {handle: $handle, url: $url})
        with twitter
        match (grantee:Grantee:Entity {name: $name}) 
        with twitter, grantee 
        merge (grantee)-[r:ACCOUNT]->(twitter)
        """
    execute_query(query, params)
    time.sleep(.5)

# %%
## ingest other grantee metadata

other_github = other_grantees_df[['name', 'github']]
other_github = other_github.dropna(subset=['github'])

for index, row in other_github.iterrows():
    url = "https://github.com.com/" + row['github'] 
    params = {
        'handle': row['github'],
        'url': url,
        'name': row['name']
    }
    query = """
        merge (github:Account:Github {handle: $handle, url: $url})
        with github
        match (grantee:Grantee:Entity {name: $name}) 
        with github, grantee 
        merge (grantee)-[r:ACCOUNT]->(github)
        """
    execute_query(query, params)
    time.sleep(.1)

# %%
## ingest other grantee metadata

other_github = other_grantees_df[['name', 'github']]
other_github = other_github.dropna(subset=['github'])

for index, row in other_github.iterrows():
    url = "https://github.com.com/" + row['github'] 
    params = {
        'handle': row['github'],
        'url': url,
        'name': row['name']
    }
    query = """
        merge (github:Account:Github {handle: $handle, url: $url})
        with github
        match (grantee:Grantee:Entity {name: $name}) 
        with github, grantee 
        merge (grantee)-[r:ACCOUNT]->(github)
        """
    execute_query(query, params)
    time.sleep(.1)

# %%
## temporarily set `.source` on other grantees to establish Arbitrum ecosystem connection
### i.e. `https://checker.gitcoin.co/public/project/show/francescoweb3-creating-educational-content-on-arbitrum`

## ingest other grantee metadata

## ingest wallets

counter = 0 
total = len(other_grantees_df)

for index, row in other_grantees_df.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} of {str(total)} records...")
    params = {
        'name': row['name'],
        'source': row['source']
    }
    
    query = """
    match (grantee:Grantee:Entity {name: $name}) 
    set grantee.source = $source
    """
    execute_query(query, params)
# Out:
# Ingesting 1 of 22 records...
# Ingesting 2 of 22 records...
# Ingesting 3 of 22 records...
# Ingesting 4 of 22 records...
# Ingesting 5 of 22 records...
# Ingesting 6 of 22 records...
# Ingesting 7 of 22 records...
# Ingesting 8 of 22 records...
# Ingesting 9 of 22 records...
# Ingesting 10 of 22 records...
# Ingesting 11 of 22 records...
# Ingesting 12 of 22 records...
# Ingesting 13 of 22 records...
# Ingesting 14 of 22 records...
# Ingesting 15 of 22 records...
# Ingesting 16 of 22 records...
# Ingesting 17 of 22 records...
# Ingesting 18 of 22 records...
# Ingesting 19 of 22 records...
# Ingesting 20 of 22 records...
# Ingesting 21 of 22 records...
# Ingesting 22 of 22 records...

# %% [markdown]
# # Ingest grants
#
# ### `grants.csv`
# Link grantees to grant metadata. Grantees may have multiple grants from different grant initiatives
#
# ```(g:Grantee)<-[r:GRANTEE]-(gr:Grant:GrantInitiative: {metadata..})-[:FUNDED]-(e:Funder)```
#
#
# **Grant Initiative**
#
# ### Todos
# - Find document announcing/outlining parameters for each grant initiative.
#
# ```
# {
#     "name": *name of grant program or, if direct, grant announcement*,
#     "grantPlatform": *if applicable, platform used to administer/fund grant*,
#     "tokenAddress": token contract address
# }
# ```
#
# **GRANTEE relationsip**
#
# ```
# {
#     "grantApprovalAction": *Action to approve grant, https://snapshot.org/#/arbitrumfoundation.eth/proposal/...*
#     "grantSubmissionUrl": *Grantee published document outlining work done for grant*,
#     "fundingAuthAction": *Action to distribute funds, multisig tx (coming soon), i.e. tally.xyz/gov/arbitrum/proposal*...,
#     "percVoteWon": *if available, percentage of voters won*,
#     "tokenAddress": *token grant paid out in*,
#     "amount": *count of token granted*,
# }
# ```
#
# **Funder**
#
# More metadata to come...
#
# ```
# {
#     "name": i.e. Arbitrum Foundation
# }
# ```

# %%
grants_df = pd.read_csv('inputs/grants_initial.csv')
print(f"There are {len(grants_df)} grants to ingest")
grants_df.head(5)
# Out:
# There are 139 grants to ingest
#     A           name Funding Platform   Amount  \
# 0 NaN          WOOFi            Tally  1000000
# 1 NaN  Gains Network            Tally  7000000
# 2 NaN       DefiEdge            Tally   200000
# 3 NaN        Synapse            Tally  2000000
# 4 NaN    PancakeSwap            Tally   200000
#
#                                  Grant Approval Vote Grant Approval Type  \
# 0  https://snapshot.org/#/arbitrumfoundation.eth/...            Snapshot
# 1  https://snapshot.org/#/arbitrumfoundation.eth/...                 NaN
# 2  https://snapshot.org/#/arbitrumfoundation.eth/...                 NaN
# 3  https://snapshot.org/#/arbitrumfoundation.eth/...                 NaN
# 4  https://snapshot.org/#/arbitrumfoundation.eth/...                 NaN
#
#                           Funding Authorization Vote Voting Plurality  \
# 0  https://www.tally.xyz/gov/arbitrum/proposal/13...           82.61%
# 1  https://www.tally.xyz/gov/arbitrum/proposal/13...           93.92%
# 2  https://www.tally.xyz/gov/arbitrum/proposal/13...           99.38%
# 3  https://www.tally.xyz/gov/arbitrum/proposal/13...           72.32%
# 4  https://www.tally.xyz/gov/arbitrum/proposal/13...           88.37%
#
#                                           Submission               Funder  \
# 0  https://forum.arbitrum.foundation/t/woofi-fina...  Arbitrum Foundation
# 1  https://forum.arbitrum.foundation/t/gains-netw...  Arbitrum Foundation
# 2  https://forum.arbitrum.foundation/t/defiedge-f...  Arbitrum Foundation
# 3  https://snapshot.org/#/arbitrumfoundation.eth/...  Arbitrum Foundation
# 4  https://forum.arbitrum.foundation/t/pancakeswa...  Arbitrum Foundation
#
#   Grant Initiative                         Grant Token Address  Count Voters
# 0   STIP - Round 1  0x912ce59144191c1204e64559fe8253a0e49e6548           NaN
# 1   STIP - Round 1  0x912ce59144191c1204e64559fe8253a0e49e6548           NaN
# 2   STIP - Round 1  0x912ce59144191c1204e64559fe8253a0e49e6548           NaN
# 3   STIP - Round 1  0x912ce59144191c1204e64559fe8253a0e49e6548           NaN
# 4   STIP - Round 1  0x912ce59144191c1204e64559fe8253a0e49e6548           NaN

# %%
### create grant/grant initiatives

grant_initiatives_df = grants_df[['Grant Initiative', 'Funding Platform', 'Grant Token Address']]
unique_grant_initiatives_df = grant_initiatives_df.drop_duplicates()
counter = 0 
total = len(unique_grant_initiatives_df)
print(f"Ingesting {str(total)} grants...")

for index, row in unique_grant_initiatives_df.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} out of {str(total)} records...")

    params = {
        'name': row['Grant Initiative'],
        'grantPlatform': row['Funding Platform'],
        'tokenAddress': row['Grant Token Address']
    }

    query = """
    merge (grant:GrantInitiative:Grant {name: $name})
    set grant.grantPlatform = $grantPlatform
    set grant.tokenAddress = $tokenAddress
    """
    execute_query(query, params)
# Out:
# Ingesting 11 grants...
# Ingesting 1 out of 11 records...
# Ingesting 2 out of 11 records...
# Ingesting 3 out of 11 records...
# Ingesting 4 out of 11 records...
# Ingesting 5 out of 11 records...
# Ingesting 6 out of 11 records...
# Ingesting 7 out of 11 records...
# Ingesting 8 out of 11 records...
# Ingesting 9 out of 11 records...
# Ingesting 10 out of 11 records...
# Ingesting 11 out of 11 records...

# %%
### connect grantees
counter = 0 
total = len(grants_df)
print(f"Ingesting {str(total)} grantee to grant rels...")

for index, row in grants_df.iterrows():
    counter += 1
    print(f"Ingesting {str(counter)} out of {str(total)} records...")

    params = {
        'name': row['name'],
        'grantInitiative': row['Grant Initiative'],
        'grantApprovalAction': row['Grant Approval Vote'],
        'grantSubmission': row['Submission'],
        'fundingAuthAction': row['Funding Authorization Vote'],
        'percVoteWon': row['Voting Plurality'],
        'tokenAddress': row['Grant Token Address'],
        'amount': row['Amount']
    }

    query = """
    match (grant:GrantInitiative:Grant {name: $grantInitiative})
    match (grantee:Grantee:Entity {name: $name})
    with grant, grantee
    merge (grant)-[r:GRANTEE]->(grantee)
    set r.amount = $amount
    set r.tokenAddress = $tokenAddress
    set r.percVoteWon = $percVoteWon
    set r.grantSubmission = $grantSubmission
    set r.grantApprovalAction = $grantApprovalAction
    """
    execute_query(query, params)
# Out:
# Ingesting 139 grantee to grant rels...
# Ingesting 1 out of 139 records...
# Ingesting 2 out of 139 records...
# Ingesting 3 out of 139 records...
# Ingesting 4 out of 139 records...
# Ingesting 5 out of 139 records...
# Ingesting 6 out of 139 records...
# Ingesting 7 out of 139 records...
# Ingesting 8 out of 139 records...
# Ingesting 9 out of 139 records...
# Ingesting 10 out of 139 records...
# Ingesting 11 out of 139 records...
# Ingesting 12 out of 139 records...
# Ingesting 13 out of 139 records...
# Ingesting 14 out of 139 records...
# Ingesting 15 out of 139 records...
# Ingesting 16 out of 139 records...
# Ingesting 17 out of 139 records...
# Ingesting 18 out of 139 records...
# Ingesting 19 out of 139 records...
# Ingesting 20 out of 139 records...
# Ingesting 21 out of 139 records...
# Ingesting 22 out of 139 records...
# Ingesting 23 out of 139 records...
# Ingesting 24 out of 139 records...
# Ingesting 25 out of 139 records...
# Ingesting 26 out of 139 records...
# Ingesting 27 out of 139 records...
# Ingesting 28 out of 139 records...
# Ingesting 29 out of 139 records...
# Ingesting 30 out of 139 records...
# Ingesting 31 out of 139 records...
# Ingesting 32 out of 139 records...
# Ingesting 33 out of 139 records...
# Ingesting 34 out of 139 records...
# Ingesting 35 out of 139 records...
# Ingesting 36 out of 139 records...
# Ingesting 37 out of 139 records...
# Ingesting 38 out of 139 records...
# Ingesting 39 out of 139 records...
# Ingesting 40 out of 139 records...
# Ingesting 41 out of 139 records...
# Ingesting 42 out of 139 records...
# Ingesting 43 out of 139 records...
# Ingesting 44 out of 139 records...
# Ingesting 45 out of 139 records...
# Ingesting 46 out of 139 records...
# Ingesting 47 out of 139 records...
# Ingesting 48 out of 139 records...
# Ingesting 49 out of 139 records...
# Ingesting 50 out of 139 records...
# Ingesting 51 out of 139 records...
# Ingesting 52 out of 139 records...
# Ingesting 53 out of 139 records...
# Ingesting 54 out of 139 records...
# Ingesting 55 out of 139 records...
# Ingesting 56 out of 139 records...
# Ingesting 57 out of 139 records...
# Ingesting 58 out of 139 records...
# Ingesting 59 out of 139 records...
# Ingesting 60 out of 139 records...
# Ingesting 61 out of 139 records...
# Ingesting 62 out of 139 records...
# Ingesting 63 out of 139 records...
# Ingesting 64 out of 139 records...
# Ingesting 65 out of 139 records...
# Ingesting 66 out of 139 records...
# Ingesting 67 out of 139 records...
# Ingesting 68 out of 139 records...
# Ingesting 69 out of 139 records...
# Ingesting 70 out of 139 records...
# Ingesting 71 out of 139 records...
# Ingesting 72 out of 139 records...
# Ingesting 73 out of 139 records...
# Ingesting 74 out of 139 records...
# Ingesting 75 out of 139 records...
# Ingesting 76 out of 139 records...
# Ingesting 77 out of 139 records...
# Ingesting 78 out of 139 records...
# Ingesting 79 out of 139 records...
# Ingesting 80 out of 139 records...
# Ingesting 81 out of 139 records...
# Ingesting 82 out of 139 records...
# Ingesting 83 out of 139 records...
# Ingesting 84 out of 139 records...
# Ingesting 85 out of 139 records...
# Ingesting 86 out of 139 records...
# Ingesting 87 out of 139 records...
# Ingesting 88 out of 139 records...
# Ingesting 89 out of 139 records...
# Ingesting 90 out of 139 records...
# Ingesting 91 out of 139 records...
# Ingesting 92 out of 139 records...
# Ingesting 93 out of 139 records...
# Ingesting 94 out of 139 records...
# Ingesting 95 out of 139 records...
# Ingesting 96 out of 139 records...
# Ingesting 97 out of 139 records...
# Ingesting 98 out of 139 records...
# Ingesting 99 out of 139 records...
# Ingesting 100 out of 139 records...
# Ingesting 101 out of 139 records...
# Ingesting 102 out of 139 records...
# Ingesting 103 out of 139 records...
# Ingesting 104 out of 139 records...
# Ingesting 105 out of 139 records...
# Ingesting 106 out of 139 records...
# Ingesting 107 out of 139 records...
# Ingesting 108 out of 139 records...
# Ingesting 109 out of 139 records...
# Ingesting 110 out of 139 records...
# Ingesting 111 out of 139 records...
# Ingesting 112 out of 139 records...
# Ingesting 113 out of 139 records...
# Ingesting 114 out of 139 records...
# Ingesting 115 out of 139 records...
# Ingesting 116 out of 139 records...
# Ingesting 117 out of 139 records...
# Ingesting 118 out of 139 records...
# Ingesting 119 out of 139 records...
# Ingesting 120 out of 139 records...
# Ingesting 121 out of 139 records...
# Ingesting 122 out of 139 records...
# Ingesting 123 out of 139 records...
# Ingesting 124 out of 139 records...
# Ingesting 125 out of 139 records...
# Ingesting 126 out of 139 records...
# Ingesting 127 out of 139 records...
# Ingesting 128 out of 139 records...
# Ingesting 129 out of 139 records...
# Ingesting 130 out of 139 records...
# Ingesting 131 out of 139 records...
# Ingesting 132 out of 139 records...
# Ingesting 133 out of 139 records...
# Ingesting 134 out of 139 records...
# Ingesting 135 out of 139 records...
# Ingesting 136 out of 139 records...
# Ingesting 137 out of 139 records...
# Ingesting 138 out of 139 records...
# Ingesting 139 out of 139 records...

# %%
## connect funders

daos =  ['Arbitrum Foundation', 'Uniswap', 'Allo Protocol', 'Gitcoin', ]
companies = ['Questbook', 'Buidlbox']

# %%
for i in daos:
    execute_query(f"""merge (dao:Dao:Entity {{name: '{i}'}})""")

# %%
for i in companies:
    execute_query(f"""merge (company:Company:Entity {{name: '{i}'}})""")

# %%
execute_query("""match (n:Entity {name:"Arbitrum Foundation"}) 
match (grant:Grant) where grant.grantPlatform = 'Tally'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         1

# %%
execute_query("""match (n:Entity {name:"Uniswap"}) 
match (grant:Grant) where grant.grantPlatform = 'Gitcoin'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         3

# %%
execute_query("""match (n:Entity {name:"Arbitrum Foundation"}) 
match (grant:Grant) where grant.grantPlatform = 'Gitcoin'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         3

# %%
execute_query("""match (n:Entity {name:"Arbitrum Foundation"}) 
match (grant:Grant) where grant.grantPlatform = 'Gitcoin'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         3

# %%
execute_query("""match (n:Entity {name:"Arbitrum Foundation"}) 
match (grant:Grant) where grant.grantPlatform = 'Questbook'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         3

# %%
execute_query("""match (n:Entity {name:"Questbook"}) 
match (grant:Grant) where grant.grantPlatform = 'Questbook'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         6

# %%
execute_query("""match (n:Entity {name:"Gitcoin"}) 
match (grant:Grant) where grant.grantPlatform = 'Questbook'
with grant, n
merge (n)-[r:FUNDED]->(grant)
return count(r)""")
# Out:
#    count(r)
# 0         3

# %%
execute_query("""
match (n:Grantee)-[]-(grant:Grant)
where n.name in ['DAO Driven Crowdfunding', 'Spray', 'Convction Voting App',
'Build3r Labs', 'AGDM', 'Magari', 'SolidGrant', 'Alloiance', 'Buidl3r', 'Allo Explorer']
with grant
match (x:Entity)
where x.name in ['Arbitrum Foundation', 'Allo Protocol', 'Gitcoin', 'Buidlbox']
MERGE (x)-[r:FUNDED]->(grant)""")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
